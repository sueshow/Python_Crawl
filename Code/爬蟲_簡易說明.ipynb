搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aoyuge">搜尋看板內 oyuge 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1664787487.A.621.html">Re: [新聞] 台台併聽證會在即 中華電3千字訴求繳回超標頻寬</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">DoncicInPTT</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E5%8F%B0%E5%8F%B0%E4%BD%B5%E8%81%BD%E8%AD%89%E6%9C%83%E5%9C%A8%E5%8D%B3&#43;%E4%B8%AD%E8%8F%AF%E9%9B%BB3%E5%8D%83%E5%AD%97%E8%A8%B4%E6%B1%82%E7%B9%B3%E5%9B%9E%E8%B6%85%E6%A8%99%E9%A0%BB%E5%AF%AC">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3ADoncicInPTT">搜尋看板內 DoncicInPTT 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1632715576.A.195.html">[公告] MobileComm板規</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ginlom</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;MobileComm%E6%9D%BF%E8%A6%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aginlom">搜尋看板內 ginlom 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/27</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">94</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1654840973.A.B2A.html">[公告] 置底閒聊區 (2022下半年)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ginlom</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E5%8D%80&#43;%282022%E4%B8%8B%E5%8D%8A%E5%B9%B4%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aginlom">搜尋看板內 ginlom 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 6/10</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script defer src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" data-cf-beacon='{"rayId":"7544ee96fec5af60","version":"2022.8.1","r":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","si":100}' crossorigin="anonymous"></script>
# </body>
# </html>

# %%
soup = BeautifulSoup(r.text, 'html.parser') #將網頁資料以html.parser
# print(soup)
sel = soup.select('div.title a') #取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
print(sel)
# Out:
# [<a href="/bbs/MobileComm/M.1664730965.A.476.html">[購機] 30k左右s22+ 或等s23</a>, <a href="/bbs/MobileComm/M.1664757370.A.A51.html">[問題] realme 6i 鍵盤區域無法返回手勢</a>, <a href="/bbs/MobileComm/M.1664759184.A.63A.html">[討論] 捨不得亞太被遠傳合併...</a>, <a href="/bbs/MobileComm/M.1664762339.A.A5E.html">[方案] 台哥大 好速成雙</a>, <a href="/bbs/MobileComm/M.1664770557.A.47D.html">[問題] 台哥大在美國沒訊號？</a>, <a href="/bbs/MobileComm/M.1664771801.A.354.html">[購機] 8k左右，台灣沒進的手機</a>, <a href="/bbs/MobileComm/M.1664772859.A.947.html">[購機] 8K內 三星A33 vs M33</a>, <a href="/bbs/MobileComm/M.1664773011.A.324.html">Re: [心得] 遠傳的續約方案超雷</a>, <a href="/bbs/MobileComm/M.1664773105.A.A4C.html">[購機] 1萬上下CP值安卓機(常打遊戲)</a>, <a href="/bbs/MobileComm/M.1664773285.A.CF8.html">[問題] 請問realme neo系列有巨集功能嗎</a>, <a href="/bbs/MobileComm/M.1664773545.A.5A0.html">[心得] 三星s20系列2年一到就會冒綠線</a>, <a href="/bbs/MobileComm/M.1664773756.A.573.html">[購機] 安卓,不傷眼,相機優,15K以下選擇?</a>, <a href="/bbs/MobileComm/M.1664773967.A.61D.html">[問題] 發行未滿一年卻有過保機？</a>, <a href="/bbs/MobileComm/M.1664780923.A.306.html">[心得] 5G和4G上網很沒感...我錯在哪裡???</a>, <a href="/bbs/MobileComm/M.1664782062.A.891.html">[問題] 買一代pixel上傳google相簿?</a>, <a href="/bbs/MobileComm/M.1664783752.A.8DE.html">[心得] S pen糟糕的換筆芯體驗</a>, <a href="/bbs/MobileComm/M.1664784226.A.C62.html">[購機]  20k內安卓手機推薦</a>, <a href="/bbs/MobileComm/M.1664786431.A.CB5.html">[新聞] 逾五成民眾舊手機放家裡閒置 環保署10月</a>, <a href="/bbs/MobileComm/M.1664787487.A.621.html">Re: [新聞] 台台併聽證會在即 中華電3千字訴求繳回超標頻寬</a>, <a href="/bbs/MobileComm/M.1632715576.A.195.html">[公告] MobileComm板規</a>, <a href="/bbs/MobileComm/M.1654840973.A.B2A.html">[公告] 置底閒聊區 (2022下半年)</a>]

# %%
for s in sel:
    print(s['href'], s.text)
# Out:
# /bbs/MobileComm/M.1664730965.A.476.html [購機] 30k左右s22+ 或等s23
# /bbs/MobileComm/M.1664757370.A.A51.html [問題] realme 6i 鍵盤區域無法返回手勢
# /bbs/MobileComm/M.1664759184.A.63A.html [討論] 捨不得亞太被遠傳合併...
# /bbs/MobileComm/M.1664762339.A.A5E.html [方案] 台哥大 好速成雙
# /bbs/MobileComm/M.1664770557.A.47D.html [問題] 台哥大在美國沒訊號？
# /bbs/MobileComm/M.1664771801.A.354.html [購機] 8k左右，台灣沒進的手機
# /bbs/MobileComm/M.1664772859.A.947.html [購機] 8K內 三星A33 vs M33
# /bbs/MobileComm/M.1664773011.A.324.html Re: [心得] 遠傳的續約方案超雷
# /bbs/MobileComm/M.1664773105.A.A4C.html [購機] 1萬上下CP值安卓機(常打遊戲)
# /bbs/MobileComm/M.1664773285.A.CF8.html [問題] 請問realme neo系列有巨集功能嗎
# /bbs/MobileComm/M.1664773545.A.5A0.html [心得] 三星s20系列2年一到就會冒綠線
# /bbs/MobileComm/M.1664773756.A.573.html [購機] 安卓,不傷眼,相機優,15K以下選擇?
# /bbs/MobileComm/M.1664773967.A.61D.html [問題] 發行未滿一年卻有過保機？
# /bbs/MobileComm/M.1664780923.A.306.html [心得] 5G和4G上網很沒感...我錯在哪裡???
# /bbs/MobileComm/M.1664782062.A.891.html [問題] 買一代pixel上傳google相簿?
# /bbs/MobileComm/M.1664783752.A.8DE.html [心得] S pen糟糕的換筆芯體驗
# /bbs/MobileComm/M.1664784226.A.C62.html [購機]  20k內安卓手機推薦
# /bbs/MobileComm/M.1664786431.A.CB5.html [新聞] 逾五成民眾舊手機放家裡閒置 環保署10月
# /bbs/MobileComm/M.1664787487.A.621.html Re: [新聞] 台台併聽證會在即 中華電3千字訴求繳回超標頻寬
# /bbs/MobileComm/M.1632715576.A.195.html [公告] MobileComm板規
# /bbs/MobileComm/M.1654840973.A.B2A.html [公告] 置底閒聊區 (2022下半年)

# %% [markdown]
# ### 範例二：爬多頁資料

# %% [markdown]
# * [Day-2 Python爬蟲小人生(2)](https://ithelp.ithome.com.tw/articles/10202493)

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.ptt.cc/bbs/joke/index.html')
soup = BeautifulSoup(r.text, 'html.parser')
u = soup.select('div.btn-group.btn-group-paging a')#上一頁按鈕的a標籤
print(u)
# Out:
# [<a class="btn wide" href="/bbs/joke/index1.html">最舊</a>, <a class="btn wide" href="/bbs/joke/index8148.html">‹ 上頁</a>, <a class="btn wide disabled">下頁 ›</a>, <a class="btn wide" href="/bbs/joke/index.html">最新</a>]

# %%
url = 'https://www.ptt.cc'+ u[1]['href'] #組合出上一頁的網址
url
# Out:
# 'https://www.ptt.cc/bbs/joke/index8148.html'

# %% [markdown]
# ### 範例三：遇到按鈕

# %% [markdown]
# #### 方法一：request.read

# %% [markdown]
# * [Python 網路爬蟲 Web Crawler 基本教學 By 彭彭](https://www.youtube.com/watch?v=9Z9xKWfNo7k)
#
# * [Python 網路爬蟲 Web Crawler 教學 - Cookie 操作實務 By 彭彭](https://www.youtube.com/watch?v=BEA7F9ExiPY)

# %% [markdown]
# 說明：
# * Cookie：網站存放在瀏覽器的一小段內容
# * 與伺服器互動：連線時，Cookie 放在 Request Headers 中送出
# * 透過「檢視原始碼」→「Application」→「Cookies」觀察重要的 Cookie

# %%
import urllib.request as req
from bs4 import BeautifulSoup

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'

# 建立一個 Request 物件，附加 Headers
header = {
           'cookie': 'over18=1',
           'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
}

request = req.Request(url, headers=header)

# 抓取網頁原始碼
with req.urlopen(request) as response:
    data = response.read().decode('utf-8')

#print(data)

# %%
# 解析原始碼，取得每篇文章的標題
# 讓 beautifulsoup協助我們解析 HTML 格式文件
root = BeautifulSoup(data, 'html.parser')

# %% [markdown]
# ##### 找尋單一標籤

# %%
# 尋找 class='title' 的 div 標籤
titles = root.find('div', class_='title')
print(titles.a.string)
# Out:
# [問卦] 送妹子知名品牌千層會太大手筆嗎？

# %% [markdown]
# ##### 找尋所有標籤

# %%
# 尋找所有 class='title' 的 div 標籤
titles = root.find_all('div', class_='title')
for title in titles:
    if title.a != None: #如果標題包含 a標籤(沒有被刪除)→印出來
        print(title.a.string)
# Out:
# [問卦] 送妹子知名品牌千層會太大手筆嗎？
# [問卦] 去7-11被要求口罩戴好該怎麼辦
# [問卦] ptt男子/女子圖鑑要怎麼寫？
# [問卦] 新竹球場10月仍無法使用，場地改至天母
# [問卦] 要達到年薪50萬並不困難吧？
# [問卦] 為啥鄉民只討論「讓子彈飛」？
# [問卦] 浩劫重生那顆球不見時主角為啥崩潰
# [問卦] 疫情是不是造就了一堆巷口小吃出名？
# [問卦] Hub買綠聯這牌子如何啊？ = =
# [新聞] 台積電市值狂跌近7兆　謝金河：價值崩壞
# [問卦] Why全世界只有澳洲不知道怎麼處理兔子？
# [問卦] google是不是開始搶錢了
# [公告] 八卦板板規(2022.02.21)
# [公告] 批踢踢27週年活動宣導公告更新 最終回
# [協尋] ［桃園］9/13 0845-0855文中路往中壢方向
# [協尋] 新北市永和區環河東路三段76號，往秀朗
# [協尋] 9月12日晚間11：10-11：2台中大道七段與

# %% [markdown]
# ##### 抓取下一頁的連結

# %%
# 找到內文是「‹ 上頁」的 a 標籤
nextlink= root.find('a', string='‹ 上頁')
print(nextlink)
print(nextlink['href'])
# Out:
# <a class="btn wide" href="/bbs/Gossiping/index38886.html">‹ 上頁</a>
# /bbs/Gossiping/index38886.html

# %% [markdown]
# ##### 整理程式

# %%
def getData(url):
#     url = 'https://www.ptt.cc/bbs/Gossiping/index.html'

    # 建立一個 Request 物件，附加 Headers
    header = {
               'cookie': 'over18=1',
               'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
    }

    request = req.Request(url, headers=header)

    # 抓取網頁原始碼
    with req.urlopen(request) as response:
        data = response.read().decode('utf-8')

    # 解析原始碼，取得每篇文章的標題
    # 讓 beautifulsoup協助我們解析 HTML 格式文件
    root = BeautifulSoup(data, 'html.parser')

    # 尋找所有 class='title' 的 div 標籤
    titles = root.find_all('div', class_='title')
    for title in titles:
        if title.a != None: #如果標題包含 a標籤(沒有被刪除)→印出來
            print(title.a.string)

    # 找到內文是「‹ 上頁」的 a 標籤
    nextlink= root.find('a', string='‹ 上頁')
    print('='*20)
    return(nextlink['href'])

# %%
# 主程序
# 抓取多頁面的標題
pageURL = 'https://www.ptt.cc/bbs/Gossiping/index.html'
count = 0
while count<3:
    pageURL = 'https://www.ptt.cc'+getData(pageURL)
    count +=1
# Out:
# [問卦] 送妹子知名品牌千層會太大手筆嗎？
# [問卦] 去7-11被要求口罩戴好該怎麼辦
# [問卦] ptt男子/女子圖鑑要怎麼寫？
# [問卦] 新竹球場10月仍無法使用，場地改至天母
# [問卦] 要達到年薪50萬並不困難吧？
# [問卦] 為啥鄉民只討論「讓子彈飛」？
# [問卦] 浩劫重生那顆球不見時主角為啥崩潰
# [問卦] 疫情是不是造就了一堆巷口小吃出名？
# [問卦] Hub買綠聯這牌子如何啊？ = =
# [新聞] 台積電市值狂跌近7兆　謝金河：價值崩壞
# [問卦] Why全世界只有澳洲不知道怎麼處理兔子？
# [問卦] google是不是開始搶錢了
# [公告] 八卦板板規(2022.02.21)
# [公告] 批踢踢27週年活動宣導公告更新 最終回
# [協尋] ［桃園］9/13 0845-0855文中路往中壢方向
# [協尋] 新北市永和區環河東路三段76號，往秀朗
# [協尋] 9月12日晚間11：10-11：2台中大道七段與
# ====================
# [問卦] 近視增加到一定程度會瞎掉嗎???
# [問卦] 台灣窮人多嗎？
# [問卦] 魚骨圖是什麼魚
# Re: [問卦] 為什麼離職原因一定要寫生涯規劃？
# Re: [新聞] 高虹安「戰學歷」致命傷害 最新民調：沈
# [問卦] 35女同事問是不是喜歡妹阿 怎回比較禮貌?
# [問卦] 海馬是不是菜B
# Re: [問卦] 買了一台 Switch 後該玩什麼遊戲?
# [問卦] 瑞信跟英國誰比較有可能搞出金融風暴?
# [問卦] htc one m8都沒有更新 是不是變孤兒
# Re: [新聞] 雙城該續辦 黃珊珊：鄰居這麼兇 不用每
# Re: [問卦] 為什麼離職原因一定要寫生涯規劃？
# [問卦] 「白晝之夜」和「中島設計」都擠？
# [問卦] 有在關注外國正妹嗎
# [問卦] 什麼條件能讓資策會供養？
# [新聞] 蔡英文：政府發放5000元育兒津貼已入帳
# [新聞] 20歲王牌AV女優小倉七海宣布引退！　一劍
# [問卦] 士林夜市可以改邪歸正嗎?
# Re: [問卦] 為什麼離職原因一定要寫生涯規劃？
# Re: [新聞] 2022選戰／鄭文燦論文遭控涉抄 鄭運鵬：
# ====================
# [問卦] 0056現在的價位（25.67元）適合買嗎？0.0
# [新聞] 警大聲明風波 徐國勇：不介入學倫事件
# [問卦] 42吋跟50吋電視螢幕拿來當電腦螢幕！？
# [問卦]銀行破產領不到錢
# [新聞] 國慶首發！北藝大校花kiki「巨乳擠爆國旗
# [問卦] 大家有看過 面試郭台銘嗎？
# [問卦] 國動在台灣是什麼樣的地位？
# Re: [新聞] 親綠智庫民調：沈慧虹30.4%、高虹安27.3%　「戰學歷有殺
# [問卦] 機車族是否都很想投胎？
# Re: [新聞] 警犬英勇擒匪險被爆頭！警「殺人救狗」惹
# Re: [問卦] 香港靠什麼產業撐著沒倒？
# [問卦] 憂鬱症，醫療險被拒保？
# [新聞] 「川崎忍者」翹孤輪狂飆是慣犯　豪乳正妹
# [問卦] 瑪雅文化也有出現灌腸療法喔？
# [問卦] 為什麼離職原因一定要寫生涯規劃？
# Re: [問卦] 沒人發現特拉斯是歐洲縮影嗎！
# [新聞] 侯友宜博士學位聲明羅生門 徐國勇嗆洪孟
# [問卦] 慘了最近會不會很難找工作QQ
# Re: [新聞] 彰化透天厝才完工「秒佔人行道」大違建！
# Re: [問卦] 中島美雪很像周杰倫？
# ====================

# %% [markdown]
# #### 方法二：request.post

# %% [markdown]
# * [Day-2 Python爬蟲小人生(2)](https://ithelp.ithome.com.tw/articles/10202493)

# %% [markdown]
# 說明：
# * 透過「檢視原始碼」→「Network」→「Payload」觀察重要的資訊
# * 發現封包以 POST 發送，並且封包內容有 cookie 和參數
# * 後續抓資料同方法一

# %%
import requests

# %%
r = requests.Session()
payload = { #須送之參數
    'from':'/bbs/Gossiping/index.html',
    'yes':'yes'
}
r1 = r.post('https://www.ptt.cc/ask/over18', data=payload) #將參數寫至data
#print(r1.text)
r2 = r.get('https://www.ptt.cc/bbs/Gossiping/index.html')
print(r2.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index38886.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">8</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1664791847.A.760.html">[問卦] 送妹子知名品牌千層會太大手筆嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">yasionl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%80%81%E5%A6%B9%E5%AD%90%E7%9F%A5%E5%90%8D%E5%93%81%E7%89%8C%E5%8D%83%E5%B1%A4%E6%9C%83%E5%A4%AA%E5%A4%A7%E6%89%8B%E7%AD%86%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ayasionl">搜尋看板內 yasionl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1664791930.A.B7D.html">[問卦] 去7-11被要求口罩戴好該怎麼辦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">saxpiano</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%8E%BB7-11%E8%A2%AB%E8%A6%81%E6%B1%82%E5%8F%A3%E7%BD%A9%E6%88%B4%E5%A5%BD%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Asaxpiano">搜尋看板內 saxpiano 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1664791953.A.80C.html">[問卦] ptt男子/女子圖鑑要怎麼寫？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">st797912</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;ptt%E7%94%B7%E5%AD%90%2F%E5%A5%B3%E5%AD%90%E5%9C%96%E9%91%91%E8%A6%81%E6%80%8E%E9%BA%BC%E5%AF%AB%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ast797912">搜尋看板內 st797912 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1664791956.A.988.html">[問卦] 新竹球場10月仍無法使用，場地改至天母</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">tony900735</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6
div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;google%E6%98%AF%E4%B8%8D%E6%98%AF%E9%96%8B%E5%A7%8B%E6%90%B6%E9%8C%A2%E4%BA%86">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ah0103661">搜尋看板內 h0103661 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/03</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1645455874.A.65E.html">[公告] 八卦板板規(2022.02.21)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282022.02.21%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/21</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1663144920.A.A6E.html">[公告] 批踢踢27週年活動宣導公告更新 最終回 </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%89%B9%E8%B8%A2%E8%B8%A227%E9%80%B1%E5%B9%B4%E6%B4%BB%E5%8B%95%E5%AE%A3%E5%B0%8E%E5%85%AC%E5%91%8A%E6%9B%B4%E6%96%B0&#43;%E6%9C%80%E7%B5%82%E5%9B%9E&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/14</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">16</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1663234523.A.703.html">[協尋] ［桃園］9/13 0845-0855文中路往中壢方向</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">skyline0928</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%EF%BC%BB%E6%A1%83%E5%9C%92%EF%BC%BD9%2F13&#43;0845-0855%E6%96%87%E4%B8%AD%E8%B7%AF%E5%BE%80%E4%B8%AD%E5%A3%A2%E6%96%B9%E5%90%91">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Askyline0928">搜尋看板內 skyline0928 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/15</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">33</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1663317236.A.C44.html">[協尋] 新北市永和區環河東路三段76號，往秀朗</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">spc0922</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%E6%96%B0%E5%8C%97%E5%B8%82%E6%B0%B8%E5%92%8C%E5%8D%80%E7%92%B0%E6%B2%B3%E6%9D%B1%E8%B7%AF%E4%B8%89%E6%AE%B576%E8%99%9F%EF%BC%8C%E5%BE%80%E7%A7%80%E6%9C%97">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aspc0922">搜尋看板內 spc0922 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/16</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">15</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1664456431.A.4C2.html">[協尋] 9月12日晚間11：10-11：2台中大道七段與</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">oldbigx</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;9%E6%9C%8812%E6%97%A5%E6%99%9A%E9%96%9311%EF%BC%9A10-11%EF%BC%9A2%E5%8F%B0%E4%B8%AD%E5%A4%A7%E9%81%93%E4%B8%83%E6%AE%B5%E8%88%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aoldbigx">搜尋看板內 oldbigx 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script defer src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" data-cf-beacon='{"rayId":"7544ef2bfb1bafb2","version":"2022.8.1","r":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","si":100}' crossorigin="anonymous"></script>
# </body>
# </html>

# %% [markdown]
# # 抓取 medium.com 首頁文章列表

# %% [markdown]
# ## 範例四：AJAX

# %% [markdown]
# * [Python 網路爬蟲 Web Crawler 教學 - AJAX / XHR 網站技術分析實務 By 彭彭](https://www.youtube.com/watch?v=IMOUf4BYTG8)

# %% [markdown]
# 說明(範例格式已改變)：
# * AJAX：網頁前端的 JavaScript 程式技術，通常第1次請求不帶資料，且透過多次請求取得資料並產生網頁畫面
# * 在網頁原始碼搜尋不到，肉眼看到的標題，分析網頁找到能夠抓資料的網址

# %%
import urllib.request as req
import json

# %%
url = 'https://medium.com/_/api/home-feed'

# 建立一個 Request 物件，附加 Headers
header = {
           'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
}

request = req.Request(url, headers=header)

# 抓取網頁原始碼
with req.urlopen(request) as response:
    data = response.read().decode('utf-8')  # 根據觀察，取得的資料是 JSON 格式

# %%
print(data)
# Out:
# ])}while(1);</x>{"success":true,"payload":{"streamItems":[{"createdAt":1664792316107,"heading":{"text":"Technology","heading":{"fallbackTitle":"Technology","headingWithLink":{"title":"Technology","linkText":"Technology","linkUrl":"/topic/technology","subtitle":"The download.","headingIcon":1},"headingType":"headingWithLink"}},"randomId":"5591aabd3a30","itemType":"heading","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"32c613fd504","extremePostPreview":{"postId":"46d6e3439989"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"a11da062b903","extremePostPreview":{"postId":"152a4463bbe8"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"ffc4e5d8940f","extremePostPreview":{"postId":"44e53a7603c5"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"83ec7b638f5e","extremePostPreview":{"postId":"917ab3d4643f"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"c7a470e6e37e","extremePostPreview":{"postId":"1da102e840a9"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"heading":{"text":"Creativity","heading":{"fallbackTitle":"Creativity","headingWithLink":{"title":"Creativity","linkText":"Creativity","linkUrl":"/topic/creativity","subtitle":"Of muses and mistakes.","headingIcon":1},"headingType":"headingWithLink"}},"randomId":"394bab74a734","itemType":"heading","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"f9be9ca9bbee","extremePostPreview":{"postId":"49d2e2516e5e"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"87d49d36fa58","extremePostPreview":{"postId":"d62d0a77b4ef"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"9b77973f65f6","extremePostPreview":{"postId":"2ec0d7480661"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"cfa4542677b","extremePostPreview":{"postId":"318446320c1e"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"40a8e027ca7a","extremePostPreview":{"postId":"ca23c413bbac"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"heading":{"text":"Startups","heading":{"fallbackTitle":"Startups","headingWithLink":{"title":"Startups","linkText":"Startups","linkUrl":"/topic/startups","subtitle":"Founding, funding, and beyond.","headingIcon":1},"headingType":"headingWithLink"}},"randomId":"bcdf197b7c0e","itemType":"heading","type":"StreamItem"},{"createdAt":1664792316107,"randomId":"a940321a2270","extremePostPreview":{"postId":"46d6e3439989"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"randomId":"1ac2e49d85d3","extremePostPreview":{"postId":"8b038cd33a3"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"randomId":"b7133cf59150","extremePostPreview":{"postId":"82b6aef58569"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"randomId":"811a4ba53948","extremePostPreview":{"postId":"125195a5f06c"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"randomId":"abfed5805be","extremePostPreview":{"postId":"fbdf4d0bcc4b"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"heading":{"text":"Culture","heading":{"fallbackTitle":"Culture","headingWithLink":{"title":"Culture","linkText":"Culture","linkUrl":"/topic/culture","subtitle":"High, low, and sideways.","headingIcon":1},"headingType":"headingWithLink"}},"randomId":"f3b2df4dfeae","itemType":"heading","type":"StreamItem"},{"createdAt":1664792316108,"randomId":"6342cc1c2d08","extremePostPreview":{"postId":"b6ec8920eb89"},"itemType":"extremePostPreview","type":"StreamItem"},{"createdAt":1664792316108,"randomId":"6614ddc9c2ad","extremePostPreview":{"postId":"7d92f8c5c2b1"},"itemType":"extremePostPreview","t ...

# %%
# 解析 JSON 格式的資料，取得每篇文章的標題
# JSON資料格式：大括號是字典，中括號是列表
# 處理髒資料
data = data.replace('])}while(1);</x>','')
data = json.loads(data)  # 把原始的 JSON 資料解析成字典/列表的表示形式
#print(data)

# 取得 JSON 資料中的文章標題
posts = data['payload']['references']['Post']
for key in posts:
    post = posts[key]
    print(post['title'])
# Out:
# The True Genius of Tech Leaders
# Tesla’s New Battery Isn’t What They Said It Would Be
# How Apple Watch Alarms and Timers Save My Butt
# The Noosphere
# Why Elon Musk’s Fear of AI Is Misguided
# Weird 19th-Century Punctuation Marks You Should Try Using
# Not Everything You Need To Thrive Can Be Easily Measured
# Is AI really a threat to creators?
# 10 Mental Models for Learning Anything
# Why You Need to Know About Mixed-Methods Studies For Your Articles
# Why in the world is Figma valued at $20B?
# I Got More Investors and Customers for My Startup Once I Learned to Calibrate My “Paydar”
# The Reason My Company Can Break Marketing Rules and Yours Can’t
# How To Hire 50 Awesome People Into Your Startup
# The Long Payoff of the Ice Bucket Challenge
# Blackness Is A Cage
# The Woman Who Refused to Shake President Biden’s Hand
# Murder, They Texted
# Wrapped Around My Head and Stitched Under My Chin.
# How Companies Can Become Future-Proof
# The Future of On-Demand Commerce: Key Innovation Drivers
# Egosystems to Ecosystems
# Are You Doing Enough to Dodge Bone Fractures?
# A “Bionic Pancreas” for Type 1 Diabetes?
# The Flu Season is Coming, Be Ready
# Why It Might Be Time To Get The ‘Shingrix’ Vaccine For Shingles
# This Drug Improves the Odds You Won’t Suffer from Severe COVID
# 5 Ways to Use Google Chrome for Maximum Efficiency
# Three Rules of Solving Problems
# How to Outperform a 10x Developer
# This Kind of Rest Could Make You Happier
# Employee Expectations Are Changing, and Leaders Must Listen
# Your Employer Should Be Funding Your Commute
# Camille Perri: How I Paid the Bills While I Wrote the Book
# Xhenet Aliu: How I Paid the Bills While I Wrote the Book
# The Moral Case for Universal Basic Income
# Why Basic Jobs Are Better Than Basic Incomes
# Let’s Talk About How to Create a Content Strategy
# Let’s Talk About SWOT Analysis
# How the Internet Made Us Believe in a Flat Earth
# The Newest Face of Diet Culture Is the Instagram Butt
# How Retail Companies Fail at Checkout
# Healthcare Design Is About More Than Aesthetics

# %% [markdown]
# ## 範例五：

# %% [markdown]
# * [Python 網路爬蟲 Web Crawler 教學 - Request Data 操作實務 By 彭彭](https://www.youtube.com/watch?v=DSjVHqdbkBw)

# %% [markdown]
# * 說明
#   * 簡單的請求(不帶額外的資料)：發送請求 → 取得 HTML 網頁 → 發送簡單的請求 → 取得回應資料並產生網頁畫面
#   * 複雜的請求(帶額外的資料)：發送請求 → 取得 HTML 網頁 → 發送複雜的請求，並提供相關資料 → 取得回應資料並產生網頁畫面
#     * 請求的額外資訊：Request Payload
#       * json.dumps(Request_Payload).encode('utf-8')
#     * content-type：application/json
#     * user-agent
# * 關鍵：認出網站的 AJAX 模式，並懂得發出複雜的請求
# * Request Data：請求附帶的資料，又稱Request Payload、Request Body

# %% [markdown]
# ## Selenium

# %% [markdown]
# ### 範例：模擬

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome('D:\GitHub_彙整\GitHub_2022_爬蟲_591租屋\chromedriver.exe')
driver.get('http://www.google.com') # 更改網址以前往不同網頁
# Out:
# <ipython-input-27-9ebd67ee5a68>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:\GitHub_彙整\GitHub_2022_爬蟲_591租屋\chromedriver.exe')

# %% [markdown]
# #### 情境：搜尋輸入

# %%
# 定位搜尋框
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf.gsfi')

# 傳入字串
element.send_keys('Selenium Python')

# %%
# 點擊搜尋按鈕
button = driver.find_element(by=By.CLASS_NAME, value='gNO89b')
button.click()

# %% [markdown]
# #### 情境：刪除輸入

# %%
# 定位搜尋框
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf.gsfi')

# 傳入字串
element.send_keys('Selenium Python')

# %%
# 刪除原本已輸入的文字
element.clear()

# %% [markdown]
# #### 情境：模擬人工

# %%
"""
Set of special keys codes.
NULL = '\ue000'
CANCEL = '\ue001' # ^break
HELP = '\ue002'
BACKSPACE = '\ue003'
BACK_SPACE = BACKSPACE
TAB = '\ue004'
CLEAR = '\ue005'
RETURN = '\ue006'
ENTER = '\ue007'
SHIFT = '\ue008'
LEFT_SHIFT = SHIFT
CONTROL = '\ue009'
LEFT_CONTROL = CONTROL
ALT = '\ue00a'
LEFT_ALT = ALT
PAUSE = '\ue00b'
ESCAPE = '\ue00c'
SPACE = '\ue00d'
PAGE_UP = '\ue00e'
PAGE_DOWN = '\ue00f'
END = '\ue010'
HOME = '\ue011'
LEFT = '\ue012'
ARROW_LEFT = LEFT
UP = '\ue013'
ARROW_UP = UP
RIGHT = '\ue014'
ARROW_RIGHT = RIGHT
DOWN = '\ue015'
ARROW_DOWN = DOWN
INSERT = '\ue016'
DELETE = '\ue017'
SEMICOLON = '\ue018'
EQUALS = '\ue019'
NUMPAD0 = '\ue01a' # number pad keys
NUMPAD1 = '\ue01b'
NUMPAD2 = '\ue01c'
NUMPAD3 = '\ue01d'
NUMPAD4 = '\ue01e'
NUMPAD5 = '\ue01f'
NUMPAD6 = '\ue020'
NUMPAD7 = '\ue021'
NUMPAD8 = '\ue022'
NUMPAD9 = '\ue023'
MULTIPLY = '\ue024'
ADD = '\ue025'
SEPARATOR = '\ue026'
SUBTRACT = '\ue027'
DECIMAL = '\ue028'
DIVIDE = '\ue029'
F1 = '\ue031' # function keys
F2 = '\ue032'
F3 = '\ue033'
F4 = '\ue034'
F5 = '\ue035'
F6 = '\ue036'
F7 = '\ue037'
F8 = '\ue038'
F9 = '\ue039'
F10 = '\ue03a'
F11 = '\ue03b'
F12 = '\ue03c'
META = '\ue03d'
COMMAND = '\ue03d' 
"""

# %%
from selenium.webdriver.common.keys import Keys

# %%
# 定位搜尋框
element = driver.find_element(by=By.CLASS_NAME, value='gLFyf.gsfi')

# 傳入字串
element.send_keys('Selenium Python')

# %%
# 對想要進行複製貼上的網頁元素使用send_keys，並在同樣的send_keys內包含一起使用的功能鍵就可以了
#「複製」-「ctrl+c」
element.send_keys(Keys.CONTROL, 'c')

# %%
#「貼上」-「ctrl+v」
element.send_keys(Keys.CONTROL, 'v')

# %% [markdown]
# #### 取得網頁截圖

# %% [markdown]
# * Python Selenium 快速開始、網頁截圖 By 彭彭

# %%
# 視窗最大化
driver.maximize_window()

# %%
driver.save_screenshot('D:\GitHub_彙整\GitHub_2022_爬蟲_591租屋\screenshot-google.png')
# Out:
# True

# %%
driver.close() # 關閉瀏覽器視窗

# %% [markdown]
# ### 範例：Selenium

# %% [markdown]
# * [Python Selenium 網頁爬蟲基礎 By 彭彭](https://www.youtube.com/watch?v=ff5L6L5MTCw)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# %%
# 設定 Chrome Driver 的執行檔路徑
#options = Options()
#options.chrome_executable_path = r'D:\GitHub_彙整\GitHub_2022_爬蟲_591租屋\chromedriver.exe'

# 建立 Driver 物件實體，用程式操作瀏覽器運作
#driver = webdriver.Chrome(options=options)
driver = webdriver.Chrome(executable_path=r'D:\GitHub_彙整\GitHub_2022_爬蟲_591租屋\chromedriver.exe')

# 連線到 PTT 股票版
# 取得股票版中的文章標題
url = 'https://www.ptt.cc/bbs/Stock/index.html'
driver.get(url)
tags = driver.find_elements(By.CLASS_NAME, 'title') # 搜尋 class 屬性是 title 的所有標籤
for tag in tags:
    print(tag.text)

# 取得上一頁的文章標題
link = driver.find_element(By.LINK_TEXT, '‹ 上頁')
link.click() # 模擬使用者點擊連結
tags = driver.find_elements(By.CLASS_NAME, 'title') # 搜尋 class 屬性是 title 的所有標籤
for tag in tags:
    print(tag.text)
    
driver.close()
# Out:
# <ipython-input-38-2cbb123d43cb>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'D:\GitHub_彙整\GitHub_2022_爬蟲_591租屋\chromedriver.exe')
# [情報] 111年10月03日 櫃買法人買賣金額統計表
# [請益] 請問真的有人這樣凹單的嗎？
# [新聞] 蘋果公佈2021年供應鏈名單　3台廠進榜
# [新聞] 700億絕對報酬委託計畫 勞動部：非護盤計
# [新聞] 潤泰雙雄：每股淨值仍大於10元
# [新聞] 三商壽董座創辦人翁肇喜回鍋 掌舵後首要
# [新聞] 美銀警告：Fed須放慢升息腳步 以防信貸
# (本文已被刪除) [randy225]
# [情報] 1003 上市外資買賣超排行
# [新聞] 土耳其降息通膨再惡化 9月CPI攀上83.45%
# [新聞] 台積電跌破 500 元，就可以安心買？下半
# Re: [請益] 當市場看法太一致時
# [情報] 2022/10/3 台股漲跌停圖鑑
# [新聞] 價值崩壞年代 謝金河：台積電也逃不了
# [新聞] 摩根史坦利將退役硬碟到網路拍賣遭罰35M
# Re: [情報] 0056配息2.1元
# [情報] 1003 上市櫃外資投信買超金額排行
# [情報] 1003 上市櫃外資投信同買排行
# [公告] 股票板板規 v4.0 (2022/01/18 修正)
# [閒聊] 2022/10/03 盤中閒聊
# [標的] 1583 程泰 多
# Re: [請益] 五年內翻倍的股票
# [新聞] 雷曼兄弟慘劇重演？這家銀行驚傳瀕臨破
# [新聞] 瑞信面臨財務危機？ CDS狂飆、高管急Call
# (本文已被刪除) [DrowningPool]
# [情報] 006204、00888、00907 10月配息結果
# [新聞] 允壽險「債券重分類」是掩蓋風險？
# [閒聊] 2022/10/03 盤後閒聊
# [新聞] 股神重押蘋果推手 巴菲特摯友去世 享壽96
# [情報] 8046南電9月營收 mom+2.6% yoy+31%
# Re: [新聞] Fed官員波斯提克：年底前再升息5碼
# [請益] 00692這次會配多少股息？
# [新聞] 今年外資出逃台股金額是疫情2倍　法人看M
# [情報] 0056配息2.1元
# [情報] 3228金麗科9月營收 mom-27% yoy-26.9%
# (本文已被刪除) [DAY1986]
# [情報] 1003 上市投信買賣超排行
# [新聞] 欣銓 第三季逆勢突圍
# (本文已被刪除) [centaurjr]
# [情報] 111年10月03日 三大法人買賣金額統計表

# %%
https://www.learncodewithmike.com/2021/10/python-scrape-free-proxy-ip.html
